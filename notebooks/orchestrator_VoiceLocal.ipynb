# %% [markdown]
# # Local Voice Cloning Orchestrator
# This notebook runs the entire VibeCodingMax pipeline LOCALLY, including XTTS Voice Cloning.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path().resolve() / 'scripts'))

from config_loader import load_pipeline_config, get_active_show
from orchestrator_VoiceLocal import run_pipeline

pipeline_cfg = load_pipeline_config()
slug, show = get_active_show(None)
print('Config loaded successfully for show:', show['display_name'])

# %%
# Run the entire pipeline end-to-end locally
run_pipeline(
    topic='Evil Mortys Master Plan',
    phase='all',
    auto_approve=True
)
